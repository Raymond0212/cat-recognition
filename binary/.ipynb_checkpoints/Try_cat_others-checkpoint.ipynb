# %% [markdown]
# ## Import library

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %% [markdown]
# ## Define path & total number

# %%
path = "C:/users/cs623/.keras/datasets/personal_cats_and_dogs"
path_cat = os.path.join(path, 'cats')
path_dog = os.path.join(path, 'dogs')

# %%
num_cats = len(os.listdir(path_cat))
num_dogs = len(os.listdir(path_dog))
total_img_num = num_cats + num_dogs
print('total cat images:', num_cats)
print('total dog images:', num_dogs)
print('total images:', total_img_num)
# Out:
# total cat images: 1500
# total dog images: 2172
# total images: 3672

# %% [markdown]
# ## Train test split

# %%
batch_size = 200
epochs = 50
IMG_HEIGHT = 150
IMG_WIDTH = 150
split = 0.2
total_val = total_img_num * split
total_train = total_img_num - total_val

# %%
# Generator

train_datagen = ImageDataGenerator(rescale=1./255, validation_split=split)

#    shear_range=0.2,
#    zoom_range=0.2,
#    horizontal_flip=True,

# %%
# Load images from the disk, applies rescaling, and resizes the images

train_generator = train_datagen.flow_from_directory(
    directory=path,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=True,
    subset='training') # set as training data

validation_generator = train_datagen.flow_from_directory(
    directory=path,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=True,
    subset='validation') # set as validation data
# Out:
# Found 2938 images belonging to 2 classes.
# Found 734 images belonging to 2 classes.

# %% [markdown]
# ## Labels

# %%
import collections

def count_label(generator):
    l = len(generator)
    counter = collections.Counter()
    for i in range(l):
        _, label = generator[i]
        unique, counts = np.unique(label, return_counts=True)
        count_label = dict(zip(unique, counts))
        counter.update(count_label) 
    result = dict(counter)
    return result

# %%
train_count = count_label(train_generator)
val_count = count_label(validation_generator)

print("Training labels:")
print(train_count)
print("Validation labels:")
print(val_count)
# Out:
# Training labels:
# {0.0: 1200, 1.0: 1738}
# Validation labels:
# {0.0: 300, 1.0: 434}

# %% [markdown]
# ## Sample visualisation

# %%
sample_img_train, sample_label_train = next(train_generator)

# %%
def plotImg(img):
    fig, axes = plt.subplots(3, 5, figsize=(20, 20))
    axes = axes.flatten()
    for i, a in zip(img, axes):
        a.imshow(i)
        a.axis("off")
    plt.tight_layout()
    plt.show()

# %%
plotImg(sample_img_train[:15])

# %% [markdown]
# ## Model

# %%
model = Sequential([
    Conv2D(16, 3, padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH ,3)),
    MaxPooling2D(),
    Conv2D(32, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])
# Out:
# WARNING:tensorflow:From C:\Users\cs623\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model.compile(optimizer='adam',
             loss='binary_crossentropy',
             metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\cs623\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 20736)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               10617344
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 10,641,441
# Trainable params: 10,641,441
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train model

# %%
with tf.device('/gpu:0'):
    history = model.fit_generator(
        train_generator,
        steps_per_epoch = total_train // batch_size,
        epochs = epochs,
        validation_data = validation_generator,
        validation_steps = total_val // batch_size
    )
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# Out:
# Epoch 1/50
# 14/14 [==============================] - 21s 1s/step - loss: 0.9500 - acc: 0.5095 - val_loss: 0.6391 - val_acc: 0.5833
# Epoch 2/50
# 14/14 [==============================] - 19s 1s/step - loss: 0.6520 - acc: 0.5961 - val_loss: 0.6180 - val_acc: 0.5833
# Epoch 3/50
# 14/14 [==============================] - 19s 1s/step - loss: 0.6319 - acc: 0.5893 - val_loss: 0.5417 - val_acc: 0.6617
# Epoch 4/50
# 14/14 [==============================] - 22s 2s/step - loss: 0.5903 - acc: 0.6486 - val_loss: 0.4599 - val_acc: 0.7850
# Epoch 5/50
# 14/14 [==============================] - 22s 2s/step - loss: 0.5798 - acc: 0.6621 - val_loss: 0.4415 - val_acc: 0.8083
# Epoch 6/50
# 14/14 [==============================] - 21s 1s/step - loss: 0.5564 - acc: 0.6854 - val_loss: 0.4256 - val_acc: 0.8483
# Epoch 29/50
# 14/14 [==============================] - 25s 2s/step - loss: 0.0190 - acc: 0.9974 - val_loss: 0.8180 - val_acc: 0.8067
# Epoch 30/50
# 14/14 [==============================] - 24s 2s/step - loss: 0.0152 - acc: 0.9985 - val_loss: 0.8653 - val_acc: 0.8117
# Epoch 31/50
# 14/14 [==============================] - 24s 2s/step - loss: 0.0142 - acc: 0.9985 - val_loss: 0.9049 - val_acc: 0.8050
# Epoch 32/50
# 14/14 [==============================] - 27s 2s/step - loss: 0.0153 - acc: 0.9985 - val_loss: 0.9943 - val_acc: 0.8033
# Epoch 33/50
# 14/14 [==============================] - 32s 2s/step - loss: 0.0543 - acc: 0.9821 - val_loss: 1.1173 - val_acc: 0.7533
# Epoch 34/50
# 14/14 [==============================] - 37s 3s/step - loss: 0.0445 - acc: 0.9886 - val_loss: 0.8565 - val_acc: 0.8083
# Epoch 35/50
# 14/14 [==============================] - 41s 3s/step - loss: 0.0209 - acc: 0.9956 - val_loss: 0.9282 - val_acc: 0.8050
# Epoch 36/50
# 14/14 [==============================] - 36s 3s/step - loss: 0.0146 - acc: 0.9981 - val_loss: 1.0736 - val_acc: 0.7967
# Epoch 37/50
# 14/14 [==============================] - 39s 3s/step - loss: 0.0105 - acc: 0.9985 - val_loss: 0.9961 - val_acc: 0.8133
# Epoch 38/50
# 14/14 [==============================] - 37s 3s/step - loss: 0.0052 - acc: 1.0000 - val_loss: 1.1143 - val_acc: 0.8083
# Epoch 39/50
# 14/14 [==============================] - 27s 2s/step - loss: 0.0055 - acc: 0.9996 - val_loss: 1.0147 - val_acc: 0.8167
# Epoch 40/50
# 14/14 [==============================] - 28s 2s/step - loss: 0.0038 - acc: 0.9996 - val_loss: 1.1048 - val_acc: 0.8167
# Epoch 41/50
# 14/14 [==============================] - 33s 2s/step - loss: 0.0028 - acc: 1.0000 - val_loss: 1.1805 - val_acc: 0.8050
# Epoch 42/50
# 14/14 [==============================] - 26s 2s/step - loss: 0.0027 - acc: 0.9996 - val_loss: 1.1579 - val_acc: 0.8100
# Epoch 43/50
# 14/14 [==============================] - 46s 3s/step - loss: 0.0029 - acc: 1.0000 - val_loss: 1.1618 - val_acc: 0.8067
# Epoch 44/50
# 14/14 [==============================] - 4635s 331s/step - loss: 0.0022 - acc: 1.0000 - val_loss: 1.2078 - val_acc: 0.8033
# Epoch 45/50
# 14/14 [==============================] - 68s 5s/step - loss: 0.0017 - acc: 1.0000 - val_loss: 1.2151 - val_acc: 0.8017
# Epoch 46/50
# 14/14 [==============================] - 21s 1s/step - loss: 0.0016 - acc: 1.0000 - val_loss: 1.2589 - val_acc: 0.8050
# Epoch 47/50
# 14/14 [==============================] - 19s 1s/step - loss: 0.0014 - acc: 1.0000 - val_loss: 1.2788 - val_acc: 0.8050
# Epoch 48/50
# 14/14 [==============================] - 20s 1s/step - loss: 0.0015 - acc: 1.0000 - val_loss: 1.2781 - val_acc: 0.8017
# Epoch 49/50
# 14/14 [==============================] - 24s 2s/step - loss: 0.0012 - acc: 1.0000 - val_loss: 1.2559 - val_acc: 0.8033
# Epoch 50/50
# 14/14 [==============================] - 24s 2s/step - loss: 0.0011 - acc: 1.0000 - val_loss: 1.2780 - val_acc: 0.8033

# %% [markdown]
# ## Result visualisation

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='lower left')
plt.title('Training and Validation Loss')

plt.show()
